# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Jose-guerra2002/Jose_Rigoberto_Guerra_Rodriguez_2510832022/refs/heads/data/readmi/data/clave_A_correlacion.csv"
df = pd.read_csv(url, sep=',')
print(df.columns.tolist())
# Out:
# ['cliente_id', 'edad', 'ingresos_mensuales', 'frecuencia_compra', 'ticket_promedio', 'satisfaccion', 'reclamos', 'uso_app', 'tiempo_respuesta', 'consumo_total']

# %%
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
print("Variables numéricas:", numerical_cols)
# Out:
# Variables numéricas: ['edad', 'ingresos_mensuales', 'frecuencia_compra', 'ticket_promedio', 'satisfaccion', 'reclamos', 'uso_app', 'tiempo_respuesta', 'consumo_total']

# %% [markdown]
# ### 1. Revisión de valores nulos

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# cliente_id            0
# edad                  0
# ingresos_mensuales    0
# frecuencia_compra     0
# ticket_promedio       1
# satisfaccion          1
# reclamos              0
# uso_app               0
# tiempo_respuesta      1
# consumo_total         0
# dtype: int64

# %%
print("Estadísticas descriptivas para variables numéricas:")
display(df[numerical_cols].describe())
# Out:
# Estadísticas descriptivas para variables numéricas:
#              edad  ingresos_mensuales  frecuencia_compra  ticket_promedio  \
# count  221.000000          221.000000         221.000000       220.000000
# mean    33.981900          853.868778           7.018100        55.187273
# std     10.037187          251.337379           3.046554        16.185683
# min     18.000000          300.000000           1.000000        14.660000
# 25%     27.000000          692.000000           6.000000        42.662500
# 50%     34.000000          854.000000           7.000000        55.585000
# 75%     41.000000         1012.000000           8.000000        67.195000
# max     60.000000         1517.000000          27.000000        96.050000
#
#        satisfaccion    reclamos     uso_app  tiempo_respuesta  consumo_total
# count    220.000000  221.000000  221.000000        220.000000     221.000000
# mean       7.540409    1.556561    5.095023         21.978227     410.161448
# ...

# %%
correlation_matrix = df[numerical_cols].corr()
print("Matriz de Correlación:")
display(correlation_matrix)
# Out:
# Matriz de Correlación:
#                         edad  ingresos_mensuales  frecuencia_compra  \
# edad                1.000000           -0.007918          -0.039381
# ingresos_mensuales -0.007918            1.000000           0.052848
# frecuencia_compra  -0.039381            0.052848           1.000000
# ticket_promedio     0.134206            0.555589           0.103280
# satisfaccion       -0.104730           -0.004644           0.246912
# reclamos            0.049394            0.028543          -0.121158
# uso_app             0.027718           -0.093862           0.574399
# tiempo_respuesta    0.061536           -0.065410          -0.331774
# consumo_total       0.057357            0.299562           0.833677
#
#                     ticket_promedio  satisfaccion  reclamos   uso_app  \
# edad                       0.134206     -0.104730  0.049394  0.027718
# ingresos_mensuales         0.555589     -0.004644  0.028543 -0.093862
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación de Variables Numéricas')
plt.show()

# %% [markdown]
# ### Identificación de Correlaciones Positivas Importantes
